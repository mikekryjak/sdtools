# %%
# %load_ext autoreload
# %autoreload 2
# %aimport sdtools
from sdtools import *
from boutdata.data import BoutData
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 2688-26E9
#
#  Directory of C:\Users\Mike\OneDrive\Project\sdtools
#
# 24/02/2022  16:30    <DIR>          .
# 24/02/2022  16:30    <DIR>          ..
# 23/02/2022  16:42    <DIR>          .ipynb_checkpoints
# 24/02/2022  16:32    <DIR>          __pycache__
# 23/02/2022  15:13    <DIR>          sd5-dc2-1
# 23/02/2022  15:13    <DIR>          sd5-dc2-2
# 23/02/2022  15:13    <DIR>          sd5-dc2-3
# 24/02/2022  16:30             5,894 sdtools.py
# 23/02/2022  16:42             4,898 sdtools_f.py
# 23/02/2022  16:29    <DIR>          test1
# 23/02/2022  15:13    <DIR>          test-1
# 23/02/2022  16:29    <DIR>          test2
# 24/02/2022  16:30    <DIR>          test3
# 24/02/2022  12:19             4,275 tester.ipynb
#                3 File(s)         15,067 bytes
#               11 Dir(s)  18,468,708,352 bytes free

# %%
data = BoutData("sd5-dc2-1")
options = data["options"]
outputs = data["outputs"]

nout = options["nout"]
Ne_intended = options["sd1d:density_upstream"]
Nnorm = outputs["Nnorm"]
Ne_actual = outputs["Ne"]
rhsevals = outputs["ncalls"]
wtime = outputs["wtime"]
sum_rhsevals = sum(rhsevals)

# %%
Nnorm
# Out:
# BoutArray(1.e+20)

# %%
[print(x) for x in outputs.keys()]
# Out:
# BOUT_VERSION
# t_array
# iteration
# zperiod
# MXSUB
# MYSUB
# MZSUB
# PE_XIND
# PE_YIND
# MYPE
# MXG
# MYG
# MZG
# nx
# ny
# nz
# MZ
# NXPE
# NYPE
# NZPE
# ZMAX
# ZMIN
# ixseps1
# ixseps2
# jyseps1_1
# jyseps1_2
# jyseps2_1
# jyseps2_2
# ny_inner
# dx
# dy
# dz
# g11
# g22
# g33
# g12
# g13
# g23
# g_11
# g_22
# g_33
# g_12
# g_13
# g_23
# J
# Bxy
# G1
# G2
# G3
# has_fftw
# has_gettext
# has_lapack
# has_netcdf
# has_legacy_netcdf
# has_petsc
# has_pretty_function
# has_pvode
# has_scorep
# has_slepc
# has_sundials
# use_backtrace
# use_color
# use_openmp
# use_output_debug
# use_sigfpe
# use_signal
# use_track
# use_metric_3d
# use_msgstack
# Tnorm
# Nnorm
# Bnorm
# AA
# dneut
# Cs0
# Omega_ci
# rho_s0
# tau_e0
# mi_me
# PeSource
# NeSource
# S
# R
# E
# F
# Dn
# kappa_n
# flux_ion
# kappa_epar
# Srec
# Siz
# Frec
# Fiz
# Fcx
# Rrec
# Riz
# Rzrad
# Erec
# Eiz
# Ecx
# Rex
# Vn
# Vi
# wall_time
# wtime
# ncalls
# ncalls_e
# ncalls_i
# wtime_rhs
# wtime_invert
# wtime_comms
# wtime_io
# wtime_per_rhs
# wtime_per_rhs_e
# wtime_per_rhs_i
# tt
# hist_hi
# run_id
# run_restart_from
# Ne
# NVi
# P
# Nn
# NVn
# Pn
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
